# %% [markdown]
# #### 1. Naming Convention
# - 영문 문자와 숫자를 사용 가능
# - 대소문자를 구분
# - 문자부터 시작, 숫자는 불가능
# - _(언더스코어) 가능
# - 특수문자(+, -, *, /, @, #, $, %, ^, &, (, ), =, ?, <, >) 불가능

# %%
a = 15
_b = 3.14
# 2c = int(77) # 파이썬에서 숫자로 선언하는 변수는 사용 불가능
_7d = float(5.14)

# %%
a = 15

print(a)
# Out:
# 15

# %%
_b = 3.14
print(_b)
# Out:
# 3.14
