# %% [markdown]
# #### Alphabet in a File

# %%
import string

def file_write(file_path, content):
    with open(file_path, 'w', encoding='utf-8') as file:
        # for letter in string.ascii_uppercase:
        #     file.write(letter + ' ')
        file.write(' '.join(string.ascii_uppercase))
        

file_write('./source/23-1.txt', 'A B C D E F G')
