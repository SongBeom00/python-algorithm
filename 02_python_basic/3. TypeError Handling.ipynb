# %% [markdown]
# #### 3. TypeError Handling
#
# - 문자열 <-> 정수 연산은 형변환(Type Casting)이 필요하다
# - Calling a non-callable인 경우
# - 리스트 인덱스 타입 에러인 경우
# - 기타 타입 에러

# %%
x = "Seoul"
# y = 25 # 에러 발생
y = "25"
y = str(25)

z = x + y

print(f'x + y : {z}')
# Out:
# x + y : Seoul25

# %%
etc = "KoreaSeoul"
# print(etc()) # 문자열인데 함수처럼 출력할 경우

c = [1, 2, 3, 4, 5]
# print(c["2"]) # 리스트에 접근할 때는 정수로 접근
print(c[1:3])
# Out:
# [2, 3]
